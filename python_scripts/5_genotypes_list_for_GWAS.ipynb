# %%
import pandas as pd

# %%
data = pd.read_csv("~/desktop/uav_flood_analysis/Data/2021_Rollins5_TAMU/real_with_soil_CORRECT/210622_Rollins5_Indices_Agisoft_nosoilrem_QGISplots.csv")
data = data[['Pedigree']]
data
# Out:
#         Pedigree
# 0        Fill/HB
# 1        Fill/HB
# 2        Fill/HB
# 3        Fill/HB
# 4        Fill/HB
# ..           ...
# 598      Fill/HB
# 599      Fill/HB
# 600      Fill/HB
# 601  LH244/PHK76
# 602   LH195/MO17
#
# [603 rows x 1 columns]

# %%
df = pd.DataFrame(data)
df = df[df['Pedigree']!='Fill/HB']
df
# Out:
#               Pedigree
# 6    W10004_0290/PHK76
# 7    W10004_0498/PHK76
# 10   W10004_0884/PHK76
# 11   W10004_0037/PHK76
# 14   W10004_0065/PHK76
# ..                 ...
# 595        PHJ40/PHAJ0
# 596           B73/MO17
# 597        LH195/PHN82
# 601        LH244/PHK76
# 602         LH195/MO17
#
# [584 rows x 1 columns]

# %%
pedigrees = df['Pedigree'].tolist()
pedigrees
# Out:
# ['W10004_0290/PHK76',
#  'W10004_0498/PHK76',
#  'W10004_0884/PHK76',
#  'W10004_0037/PHK76',
#  'W10004_0065/PHK76',
#  'W10004_0103/PHK76',
#  'W10004_1007/PHK76',
#  'W10004_0168/PHK76',
#  'W10004_0950/PHK76',
#  'W10004_0080/PHK76',
#  'W10004_1112/PHK76',
#  'W10004_0827/PHK76',
#  'B37/OH43',
#  'W10004_0079/PHK76',
#  'W10004_0264/PHK76',
#  'W10004_0062/PHK76',
#  'W10004_0199/PHK76',
#  'W10004_0632/PHK76',
#  'W10004_0649/PHK76',
#  'W10004_0949/PHK76',
#  'F42/H95',
#  'W10004_0041/PHK76',
#  'LH82/TX779',
#  'W10004_0389/PHK76',
#  'TX773/TX779',
#  'W10004_0782/PHK76',
#  'W10004_0879/PHK76',
#  'W10004_0179/PHK76',
#  'W10004_0430/PHK76',
#  'W10004_0741/PHK76',
#  'W10004_0822/PHK76',
#  'W10004_0271/PHK76',
#  'W10004_0892/PHK76',
#  'W10004_0966/PHK76',
#  'W10004_0732/PHK76',
#  'W10004_0798/PHK76',
#  'W10004_0078/PHK76',
#  'W10004_0129/PHK76',
#  'B73/PHN82',
#  'W10004_0631/PHK76',
#  'W10004_1018/PHK76',
#  'W10004_0256/PHK76',
#  'W10004_0688/PHK76',
# ...
