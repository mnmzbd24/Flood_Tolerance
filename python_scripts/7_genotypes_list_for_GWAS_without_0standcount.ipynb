# %%
import pandas as pd

# %%
data = pd.read_csv("/Users/madi_mitchell/desktop/uav_flood_analysis/Data/2021_Rollins5_TAMU/real_with_soil_CORRECT/210721_Rollins5_Indices_Agisoft_nosoilrem_QGISplots.csv")
data = data[['Pedigree','NDVI']]
data
# Out:
#         Pedigree      NDVI
# 0        Fill/HB  0.641958
# 1        Fill/HB  0.683048
# 2        Fill/HB  0.661402
# 3        Fill/HB  0.598545
# 4        Fill/HB  0.581166
# ..           ...       ...
# 598      Fill/HB  0.435261
# 599      Fill/HB  0.405874
# 600      Fill/HB  0.425545
# 601  LH244/PHK76  0.417982
# 602   LH195/MO17  0.440529
#
# [603 rows x 2 columns]

# %%
df = pd.DataFrame(data)
df = df[~df['Pedigree'].isin(['Fill/HB'])]
df
# Out:
#               Pedigree      NDVI
# 6    W10004_0290/PHK76  0.662560
# 7    W10004_0498/PHK76  0.676778
# 10   W10004_0884/PHK76  0.659192
# 11   W10004_0037/PHK76  0.640619
# 14   W10004_0065/PHK76  0.685488
# ..                 ...       ...
# 595        PHJ40/PHAJ0  0.504221
# 596           B73/MO17  0.479626
# 597        LH195/PHN82  0.464814
# 601        LH244/PHK76  0.417982
# 602         LH195/MO17  0.440529
#
# [584 rows x 2 columns]

# %%
df = pd.DataFrame(data)
df = df[df['Pedigree'].isin(['W10004_0065/PHK76',
 'W10004_0103/PHK76',
 'W10004_1007/PHK76',
 'W10004_0080/PHK76',
 'W10004_1112/PHK76',
 'W10004_0827/PHK76',
 'W10004_0264/PHK76',
 'W10004_0062/PHK76',
 'W10004_0199/PHK76',
 'W10004_0649/PHK76',
 'W10004_0949/PHK76',
 'W10004_0688/PHK76',
 'W10004_0220/PHK76',
 'W10004_0008/PHK76',
 'W10004_0098/PHK76',
 'W10004_0032/PHK76',
 'W10004_0885/PHK76',
 'W10004_0093/PHK76',
 'W10004_0981/PHK76',
 'W10004_0636/PHK76',
 'LOCAL_CHECK',
 'W10004_0110/PHK76',
 'W10004_0733/PHK76',
 'W10004_0465/PHK76',
 'W10004_0774/PHK76',
 'W10004_0047/PHK76',
 'W10004_0687/PHK76',
 'W10004_0932/PHK76',
 'W10004_0171/PHK76',
 'W10004_1084/PHK76',
 'W10004_0236/PHK76',
 'W10004_0645/PHK76',
 'W10004_1004/PHK76',
 'W10004_1105/PHK76',
 'W10004_0614/PHK76',
 'W10004_0768/PHK76',
 'W10004_0501/PHK76',
 'W10004_0969/PHK76',
 'W10004_0792/PHK76',
 'W10004_0624/PHK76',
 'W10004_0799/PHK76',
 'W10004_0680/PHK76',
 'W10004_0784/PHK76',
 'W10004_0661/PHK76',
 'REDEAR/LH195',
 'W10004_0756/PHK76',
 'W10004_0814/PHK76',
 'W10004_0006/PHK76',
 'W10004_0119/PHK76',
 'W10004_0178/PHK76',
 'W10004_0922/PHK76',
 'W10004_0974/PHK76',
 'W10004_0010/PHK76',
 'W10004_0203/PHK76',
 'W10004_0346/PHK76',
 'W10004_0787/PHK76',
 'W10004_0217/PHK76',
 'B73/MO17',
 'PHG39/PHN82',
 'W10004_0843/PHK76',
 'W10004_0197/PHK76',
 'TX110/87916',
 'W10004_0474/PHK76',
 'LH195/TX779',
 'W10004_0306/PHK76',
 'W10004_0943/PHK76',
 'W10004_0309/PHK76',
 'W10004_0427/PHK76',
 'W10004_0819/PHK76',
 'W10004_0192/PHK76',
 'W10004_0996/PHK76',
 'W10004_0783/PHK76',
 'W10004_0840/PHK76',
 'W10004_0848/PHK76',
 'W10004_0707/PHK76',
 'W10004_0935/PHK76',
 'W10004_0073/PHK76',
 'W10004_0914/PHK76',
 'W10004_0913/PHK76',
 'W10004_0045/PHK76',
 'TX777/LH195',
 'W10004_0953/PHK76',
 'F42/OH43',
 'W10004_0115/PHK76',
 'W10004_0806/PHK76',
 'TX779/LH195',
 'W10004_0224/PHK76',
 'W10004_0068/PHK76',
 'W10004_0403/PHK76',
 'W10004_1063/PHK76',
 'W10004_0760/PHK76',
 'W10004_0154/PHK76',
 'W10004_0381/PHK76',
 'W10004_0800/PHK76',
 'W10004_0650/PHK76',
 'W10004_0754/PHK76',
 'W10004_0292/PHK76',
 'W10004_0727/PHK76',
 'W10004_0930/PHK76',
 'W10004_1002/PHK76',
 'W10004_0194/PHK76',
 'W10004_0383/PHK76',
 'W10004_0106/PHK76',
 'W10004_0148/PHK76',
 'W10004_0380/PHK76',
 'W10004_0916/PHK76',
 'W10004_0704/PHK76',
 'W10004_0877/PHK76',
 'W10004_0751/PHK76',
 'W10004_1037/PHK76',
 'B73/PHM49',
 'W10004_0713/PHK76',
 'W10004_0868/PHK76',
 'W10004_0055/PHK76',
 'W10004_0031/PHK76',
 'W10004_0794/PHK76',
 'B73/TX779',
 'W10004_1020/PHK76',
 'PB80/TX779',
 'W10004_0140/PHK76',
 'W10004_0242/PHK76',
 'W10004_0685/PHK76',
 'W10004_0646/PHK76',
 'W10004_0070/PHK76',
 'W10004_0982/PHK76',
 'W10004_0815/PHK76',
 'W10004_0928/PHK76',
 'W10004_0644/PHK76',
 'W10004_0149/PHK76',
 '2369/LH123HT',
 'W10004_0682/PHK76',
 'W10004_0988/PHK76',
 'W10004_0122/PHK76',
 'W10004_0153/PHK76',
 'W10004_0669/PHK76',
 'W10004_0268/PHK76',
 'W10004_0071/PHK76',
 'W10004_0064/PHK76',
 'W10004_0771/PHK76',
 'F42/MO17',
 'W10004_0818/PHK76',
 'W10004_0059/PHK76',
 'B14A/MO17',
 'CG119/CG108',
 'W10004_0836/PHK76',
 'W10004_0476/PHK76',
 'B37/H95',
 'W10004_0802/PHK76',
 'W10004_0099/PHK76',
 'TX779/LH195',
 'W10004_1099/PHK76',
 'W10004_0847/PHK76',
 'W10004_0914/PHK76',
 'W10004_0834/PHK76',
 'W10004_0412/PHK76',
 'W10004_0935/PHK76',
 'W10004_0018/PHK76',
 'W10004_0723/PHK76',
 'W10004_1156/PHK76',
 'W10004_0885/PHK76',
 'W10004_0697/PHK76',
 'W10004_0121/PHK76',
 'W10004_0166/PHK76',
 'W10004_0200/PHK76',
 'W10004_0039/PHK76',
 'W10004_0951/PHK76',
 'W10004_0035/PHK76',
 'W10004_0185/PHK76',
 'PB80/TX779',
 'W10004_0362/PHK76',
 'W10004_0913/PHK76',
 'W10004_0667/PHK76',
 'W10004_0774/PHK76',
 'W10004_0628/PHK76',
 'W10004_0412/PHK76',
 'W10004_0308/PHK76',
 'LH195/TX779',
 'W10004_1002/PHK76',
 'W10004_0844/PHK76',
 'W10004_0152/PHK76',
 'W10004_1011/PHK76',
 'W10004_0116/PHK76',
 'W10004_0646/PHK76',
 'W10004_0830/PHK76',
 'W10004_0133/PHK76',
 'W10004_0920/PHK76',
 'W10004_0026/PHK76',
 'W10004_0951/PHK76',
 'B73/MO17',
 'W10004_0206/PHK76',
 'W10004_0823/PHK76',
 'W10004_0938/PHK76',
 'W10004_0127/PHK76',
 'W10004_0705/PHK76',
 'W10004_0394/PHK76',
 'W10004_0727/PHK76',
 'W10004_0299/PHK76',
 'W10004_0626/PHK76',
 'W10004_0253/PHK76',
 'W10004_0842/PHK76',
 'W10004_1081/PHK76',
 'W10004_0086/PHK76',
 'W10004_0997/PHK76',
 'W10004_0220/PHK76',
 'W10004_0042/PHK76',
 'W10004_0751/PHK76',
 'W10004_0238/PHK76',
 'W10004_0138/PHK76',
 'W10004_1117/PHK76',
 'W10004_0106/PHK76',
 'W10004_0150/PHK76',
 'W10004_0395/PHK76',
 'F42/H95',
 'W10004_0467/PHK76',
 'W10004_0011/PHK76',
 'W10004_0956/PHK76',
 'W10004_0982/PHK76',
 'W10004_0223/PHK76',
 'W10004_0013/PHK76',
 'W10004_0789/PHK76',
 'W10004_0620/PHK76',
 'W10004_0262/PHK76',
 'W10004_0146/PHK76',
 'TX110/87916',
 'W10004_0695/PHK76',
 'W10004_0856/PHK76',
 'W10004_1112/PHK76',
 'W10004_1099/PHK76',
 'W10004_0148/PHK76',
 'W10004_0682/PHK76',
 'W10004_0859/PHK76',
 'W10004_0329/PHK76',
 'REDEAR/LH195',
 'W10004_0276/PHK76',
 'W10004_1015/PHK76',
 'W10004_0134/PHK76',
 'W10004_1014/PHK76',
 'W10004_0696/PHK76',
 'W10004_0781/PHK76',
 'W10004_0027/PHK76',
 'W10004_0038/PHK76',
 'W10004_1140/PHK76',
 'W10004_0736/PHK76',
 'W10004_0760/PHK76',
 'W10004_0270/PHK76',
 'W10004_0396/PHK76',
 'W10004_0664/PHK76',
 'W10004_0974/PHK76',
 'W10004_0487/PHK76',
 'TX773/TX779',
 'W10004_0918/PHK76',
 'W10004_0955/PHK76',
 'W10004_0840/PHK76',
 'W10004_0984/PHK76',
 'W10004_0608/PHK76',
 'W10004_0097/PHK76',
 'W10004_0812/PHK76',
 'F42/OH43',
 'W10004_0747/PHK76',
 'W10004_0046/PHK76',
 'W10004_1072/PHK76',
 'W10004_0061/PHK76',
 'W10004_0072/PHK76',
 'W10004_0110/PHK76',
 'W10004_0419/PHK76',
 'W10004_0068/PHK76',
 'B73/TX779',
 'W10004_0242/PHK76',
 'W10004_1037/PHK76',
 'W10004_1123/PHK76',
 'W10004_0891/PHK76',
 'W10004_0991/PHK76',
 'W10004_0424/PHK76',
 'B37/H95',
 'W10004_0964/PHK76',
 'W10004_0907/PHK76',
 'W10004_0672/PHK76',
 'W10004_0010/PHK76',
 'W10004_0112/PHK76',
 'W10004_0711/PHK76',
 'W10004_0953/PHK76',
 'W10004_0053/PHK76',
 'W10004_0807/PHK76',
 'W10004_0746/PHK76',
 'W10004_0654/PHK76',
 'W10004_0007/PHK76',
 'W10004_0034/PHK76',
 'W10004_0858/PHK76',
 'W10004_0787/PHK76',
 'W10004_0622/PHK76',
 'W10004_0194/PHK76',
 'W10004_0773/PHK76',
 'W10004_0261/PHK76',
 'W10004_0886/PHK76',
 'W10004_0213/PHK76',
 'W10004_0950/PHK76',
 'W10004_1084/PHK76',
 'W10004_0701/PHK76',
 'W10004_0227/PHK76',
 'W10004_0801/PHK76',
 'B37/OH43',
 'W10004_0616/PHK76',
 'W10004_0832/PHK76',
 'W10004_0118/PHK76',
 'W10004_0203/PHK76',
 'W10004_0241/PHK76',
 'W10004_0876/PHK76',
 'W10004_0691/PHK76',
 'W10004_0988/PHK76',
 'W10004_0869/PHK76',
 'W10004_0625/PHK76',
 'W10004_0032/PHK76',
 'W10004_0119/PHK76',
 'PHW52/PHN82',
 'W10004_0132/PHK76',
 'W10004_0783/PHK76',
 'W10004_0474/PHK76',
 'W10004_0820/PHK76',
 'W10004_0167/PHK76',
 'W10004_0649/PHK76',
 'W10004_0888/PHK76',
 'B73/PHM49',
 'W10004_1045/PHK76',
 'W10004_0775/PHK76',
 'W10004_0393/PHK76',
 'W10004_0196/PHK76',
 'LH74/PHN82',
 'W10004_0069/PHK76',
 'W10004_0344/PHK76',
 'W10004_0361/PHK76',
 'W10004_0037/PHK76',
 'W10004_0417/PHK76',
 'W10004_0714/PHK76',
 'W10004_0619/PHK76',
 'W10004_1004/PHK76',
 'PHG39/PHN82',
 'W10004_0221/PHK76',
 'W10004_0732/PHK76',
 'W10004_1032/PHK76',
 'W10004_0087/PHK76',
 'W10004_0828/PHK76',
 'W10004_0311/PHK76',
 '2369/LH123HT',
 'F42/MO17',
 'W10004_0410/PHK76',
 'W10004_0745/PHK76',
 'W10004_1118/PHK76',
 'W10004_0602/PHK76',
 'W10004_0689/PHK76',
 'TX777/LH195',
 'W10004_0975/PHK76',
 'W10004_0062/PHK76',
 'W10004_0268/PHK76',
 'W10004_0803/PHK76',
 'W10004_0678/PHK76',
 'W10004_0160/PHK76',
 'W10004_0008/PHK76',
 'W10004_0225/PHK76',
 'W10004_0884/PHK76',
 'W10004_0327/PHK76',
 'W10004_0675/PHK76',
 'W10004_1018/PHK76',
 'W10004_0659/PHK76',
 'W10004_0336/PHK76',
 'W10004_0784/PHK76',
 'W10004_0144/PHK76',
 'W10004_0833/PHK76',
 'W10004_0639/PHK76',
 'W10004_1146/PHK76',
 'CG119/CG108',
 'W10004_0963/PHK76',
 'B73/PHN82',
 'B14A/H95',
 'B14A/OH43',
 'W10004_0204/PHK76',
 'W10004_0779/PHK76',
 'W10004_0674/PHK76',
 'W10004_0169/PHK76',
 'W10004_0901/PHK76',
 'W10004_0889/PHK76',
 'W10004_1104/PHK76',
 'B37/MO17',
 'W10004_0894/PHK76',
 'W10004_0717/PHK76',
 'W10004_0258/PHK76',
 'W10004_0310/PHK76',
 'W10004_0254/PHK76',
 'W10004_1057/PHK76',
 'W10004_0703/PHK76',
 'W10004_0189/PHK76',
 'W10004_1000/PHK76',
 'B14A/MO17',
 'W10004_0129/PHK76',
 'W10004_0601/PHK76',
 'W10004_0076/PHK76',
 'W10004_0800/PHK76'])]
df
# Out:
#               Pedigree      NDVI
# 10   W10004_0884/PHK76  0.659192
# 11   W10004_0037/PHK76  0.640619
# 14   W10004_0065/PHK76  0.685488
# 15   W10004_0103/PHK76  0.623845
# 18   W10004_1007/PHK76  0.608779
# ..                 ...       ...
# 556           B37/OH43  0.400245
# 561           B73/MO17  0.404641
# 566          B73/PHN82  0.399544
# 581          B73/PHN82  0.403178
# 596           B73/MO17  0.479626
#
# [473 rows x 2 columns]

# %%
pedigrees = df['Pedigree'].tolist()
pedigrees
# Out:
# ['W10004_0087 X PHP02',
#  'PHG39 X PHN82',
#  'W10004_0134 X PHP02',
#  'W10004_0935 X PHP02',
#  'W10004_1118 X PHP02',
#  'W10004_0498 X PHP02',
#  'W10004_0713 X PHP02',
#  'W10004_0129 X PHP02',
#  'W10004_0798 X PHP02',
#  'B37 X H95',
#  'W10004_0053 X PHP02',
#  'W10004_0220 X PHP02',
#  'W10004_0292 X PHP02',
#  'B37 X MO17',
#  'W10004_0932 X PHP02',
#  'W10004_0818 X PHP02',
#  'W10004_0938 X PHP02',
#  'W10004_0076 X PHP02',
#  'W10004_0803 X PHP02',
#  'W10004_0078 X PHP02',
#  'W10004_0892 X PHP02',
#  'W10004_0213 X PHP02',
#  'W10004_0306 X PHP02',
#  'W10004_0970 X PHP02',
#  'W10004_0042 X PHP02',
#  'W10004_0116 X PHP02',
#  'LH195 X TX779',
#  'F42 X MO17',
#  'W10004_0664 X PHP02',
#  'F42 X H95',
#  'W10004_0035 X PHP02',
#  'W10004_1084 X PHP02',
#  'W10004_0059 X PHP02',
#  '2369 X LH123HT',
#  'W10004_0071 X PHP02',
#  'W10004_1020 X PHP02',
#  'LOCAL_CHECK',
#  'W10004_1037 X PHP02',
#  'W10004_1004 X PHP02',
#  'W10004_0832 X PHP02',
# ...

# %%
df = df.rename(columns={'Pedigree': 'taxa', 'NDVI': 'data'})
df.loc[1] = ['taxa','data']
df.index = df.index + 1
df = df.sort_index()
print(df)
# Out:
#                   taxa      data
# 2                 taxa      data
# 11   W10004_0884/PHK76  0.659192
# 12   W10004_0037/PHK76  0.640619
# 15   W10004_0065/PHK76  0.685488
# 16   W10004_0103/PHK76  0.623845
# ..                 ...       ...
# 557           B37/OH43  0.400245
# 562           B73/MO17  0.404641
# 567          B73/PHN82  0.399544
# 582          B73/PHN82  0.403178
# 597           B73/MO17  0.479626
#
# [474 rows x 2 columns]

# %%
df.to_csv('210728_NDVI_nozeros.txt', sep='\t', index=False)
